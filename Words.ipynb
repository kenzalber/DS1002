# %% [markdown]
# <a href="https://colab.research.google.com/github/kenzalber/DS1002/blob/main/Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install english_words
from english_words import get_english_words_set
words = get_english_words_set(['web2'], lower=True)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 13.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for english_words: filename=english_words-2.0.1-py3-none-any.whl size=8196238 sha256=13a3debc13969d2c8f05c0441c78f8a042f1e2ce77a0978c32e4c9c1486a2176
#   Stored in directory: /root/.cache/pip/wheels/f0/e6/d9/16a123647999fe535f03a36e7af23eef203736d84c7ca25b0b
# Successfully built english_words
# ...

# %%
#Question One:
#Orginal data type of "words" = set
wordlist = list(words)
print("Length of word list = " + str(len(wordlist))) #Prints out length of worlist

#Question Two:
print(wordlist[:10])
#All of these words are fairly complex, and don't seem to follow a distinct pattern


#Question Three:
alpha_list = sorted(wordlist)
print(alpha_list[:10])


#Question Four:
#Counts how many words start with 'a'
count_a = 0
for n in alpha_list:
  if n[0] == 'a':
    count_a+=1
print(str(count_a) + " words start with 'a'")


#Question Five:
#Counts how many words contain a 'q'
count_q = 0
for n in alpha_list:
  if 'q' in n:
    count_q+=1
print(str(count_q) + " words contain 'q'")

#Determines what percent of words do not contain an 'e'
count_e = 0
for n in alpha_list:
  if 'e' in n:
    count_e+=1
no_e = len(alpha_list) - count_e
percent_no_e = (no_e / len(alpha_list)) * 100
print(str((round(percent_no_e))) + " percent of words do not contain an 'e'")


#Question Six:
import numpy as np
wordlist = np.array(wordlist)
alpha_list = np.array(alpha_list)
alphabet = [chr(i) for i in range(ord('a'),ord('z')+1)] #creates a list containing every letter in the alphabet


#Question Seven:
import matplotlib.pyplot as plt

#Creates a list containing the counts of words starting with each letter
letter_counts = np.zeros(26)
for n in range(26):
  for i in alpha_list:
    if alphabet[n] == i[0]:
     letter_counts[n]+=1

#Creates bar graph of the number of words starting with each letter
plt.bar(alphabet, letter_counts, color='g')
plt.ylabel("Number of words")
plt.xlabel("Starting letter of word")
plt.title("Number of words starting with each letter")
plt.show()


#Question Eight:
#Six longest words in worst list
sorted_list = sorted(alpha_list, key=lambda x: len(x), reverse=True)
print(sorted_list[:6])

#Question Nine:
lengths = [len(word) for word in sorted_list]

plt.hist(lengths, bins=25)
plt.title("Frequency of the number of letters in each word")
plt.ylabel("Number of words")
plt.xlabel("Number of letters in the words")
plt.show()

#Question Eleven:
v_and_a = [word for word in sorted_list if 'v' in word and 'a' in word]
w_and_l = [word for word in sorted_list if 'w' in word and 'l' in word]
print("Number of words that contain 'v' and 'a': " + str(len(v_and_a)))
print("Number of words that contain 'w' and 'l': " + str(len(w_and_l)))
# Out:
# Length of word list = 234450
# ['archecclesiastic', 'cleruchic', 'hupa', 'ambystomidae', 'uranorrhaphia', 'synodontid', 'underbarber', 'bribegiving', 'blobby', 'bioral']
# ['a', 'aa', 'aal', 'aalii', 'aam', 'aani', 'aardvark', 'aardwolf', 'aaron', 'aaronic']
# 16982 words start with 'a'
# 3624 words contain 'q'
# 33 percent of words do not contain an 'e'
# ['antidisestablishmentarianism', 'formaldehydesulphoxylate', 'pathologicopsychological', 'scientificophilosophical', 'tetraiodophenolphthalein', 'thyroparathyroidectomize']
# Number of words that contain 'v' and 'a': 11347
# Number of words that contain 'w' and 'l': 4822
